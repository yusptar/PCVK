# %% [markdown]
# <a href="https://colab.research.google.com/github/yusptar/PCVK/blob/main/PCVK_Modul-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')
#cmap='magma'

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices 

pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
# **Jawaban**
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# **Tugas**
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
#Red-Green
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3[:,:,2] = np.zeros([img3.shape[0], img3.shape[1]])
plt.imshow(img3)

# %%
#Green-Blue
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img3[:,:,0] = np.zeros([img3.shape[0], img3.shape[1]])
plt.imshow(img3)

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img4 = img
y=10
x=10
h=100
w=100
crop_img = img4[y:y+h, x:x+w]
plt.imshow(crop_img)

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
imgHijau = img
img5=imgHijau
img5[:,:,0] = 0
img5[:,:,2] = 0
plt.imshow(img5)
y=5
h=30
crop_img = img5[y:y+h]
plt.imshow(crop_img)

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(300,400),pt2=(200,100),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(200,400),pt2=(600,300),color=(0,255,0),thickness=10)
cv.rectangle(img3,pt1=(100,400),pt2=(300,600),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(200,150),pt2=(150,250),color=(0,255,255),thickness=10)
cv.rectangle(img3,pt1=(600,450),pt2=(400,350),color=(255,255,255),thickness=10)
plt.imshow(img3)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
img = cv.imread('/content/drive/MyDrive/kitten01.jpg')
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
img6 = img
img6 = cv.cvtColor(img6, cv.COLOR_BGR2RGB)
cv.rectangle(img6, pt1=(280,50), pt2=(500,280), color=(0,255,0), thickness=10)
cv.circle(img6, center=(390,165), radius=100, color=(255,0,0), thickness=8)
plt.imshow(img6)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten01.jpg!

# %%
img7 = img
img7 = cv.cvtColor(img7, cv.COLOR_BGR2RGB)
cv.rectangle(img7, pt1=(1,527), pt2=(100,627), color=(0,255,0), thickness=5)
plt.imshow(img7)
